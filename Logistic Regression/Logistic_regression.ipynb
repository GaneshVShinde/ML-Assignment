# %%
import numpy as np
import pandas as pd

from sklearn import preprocessing
import matplotlib.pyplot as plt
import seaborn as sns

# %%
train_df = pd.read_csv("train _titanic.csv")
test_df = pd.read_csv("test _titanic.csv")
train_df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
train_df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
sum(pd.isnull(train_df['Age']))
# Out:
# 177

# %%
ax = train_df["Age"].hist(bins=15, color='teal', alpha=0.8)
ax.set(xlabel='Age', ylabel='Count')
# Out:
# [Text(0, 0.5, 'Count'), Text(0.5, 0, 'Age')]

# %%
train_df["Age"].median(skipna=True)
# Out:
# 28.0

# %%
round(687/len(train_df["PassengerId"]),4)
# Out:
# 0.771

# %%
round(2/len(train_df["PassengerId"]),4)
# Out:
# 0.0022

# %%
sns.countplot(x='Embarked',data=train_df,palette='Set2')

# %%
train_df["Age"].fillna(28, inplace=True)
train_df["Embarked"].fillna("S", inplace=True)
train_df.drop('Cabin', axis=1, inplace=True)

# %%
train2 = pd.get_dummies(train_df, columns=["Pclass"])

# %%
train3 = pd.get_dummies(train2, columns=["Embarked"])

# %% [markdown]
# # Clean  titanic data
# # Impute missing values
# # fit logistic regression
# # Use CV to figure out best cutoff probablity

# %%
dd=pd.read_csv("a.csv")

# %%
dd
# Out:
#        842302  M  17.99  10.38   122.8    1001   0.1184   0.2776   0.3001  \
# 0      842517  M  20.57  17.77  132.90  1326.0  0.08474  0.07864  0.08690
# 1    84300903  M  19.69  21.25  130.00  1203.0  0.10960  0.15990  0.19740
# 2    84348301  M  11.42  20.38   77.58   386.1  0.14250  0.28390  0.24140
# 3    84358402  M  20.29  14.34  135.10  1297.0  0.10030  0.13280  0.19800
# 4      843786  M  12.45  15.70   82.57   477.1  0.12780  0.17000  0.15780
# ..        ... ..    ...    ...     ...     ...      ...      ...      ...
# 563    926424  M  21.56  22.39  142.00  1479.0  0.11100  0.11590  0.24390
# 564    926682  M  20.13  28.25  131.20  1261.0  0.09780  0.10340  0.14400
# 565    926954  M  16.60  28.08  108.30   858.1  0.08455  0.10230  0.09251
# 566    927241  M  20.60  29.33  140.10  1265.0  0.11780  0.27700  0.35140
# 567     92751  B   7.76  24.54   47.92   181.0  0.05263  0.04362  0.00000
#
#       0.1471  ...   25.38  17.33   184.6    2019   0.1622   0.6656  0.7119  \
# ...
